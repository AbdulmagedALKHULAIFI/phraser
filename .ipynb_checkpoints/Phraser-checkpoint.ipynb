# %% [markdown]
# # Import

# %%
import nltk
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# # Installlation

# %%
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('brown')
# nltk.download('tagsets')
# nltk.download('gutenberg')
# nltk.download('genesis')
# nltk.download('inaugural')
# nltk.download('nps_chat')
# !pip install xeus-python notebook

# %% [markdown]
# # To-do list

# %% [markdown]
# - Create dictionary for the POS shortcuts
# - Create a Json answer for the API
# - Handle the space before and after "."
# - Searching by lemma/origin of the word "Clean text"

# %% [markdown]
# # Load dataset

# %%
file = open('nltk.txt')
read_file = file.read()
text = nltk.Text(nltk.word_tokenize(read_file))
tags = nltk.pos_tag(text)
words = [word for (word, pos) in nltk.pos_tag(text)]
pos = [pos for (word, pos) in nltk.pos_tag(text)]
# match = text.concordance('car')

# %%
prh = {'Words':words,'Pos':pos}
df = pd.DataFrame(prh)

# %%
df['index']= df.index

# %%
df.tail(20)
# Out:
#               Words   Pos  index
# 138            your  PRP$    138
# 139     application    NN    139
# 140               1    CD    140
# 141               ;     :    141
# 142               ;     :    142
# 143         Consult   NNP    143
# 144             the    DT    144
# 145         website    JJ    145
# 146       regularly    NN    146
# 147              to    TO    147
# 148             see    VB    148
# 149           other    JJ    149
# 150            open    JJ    150
# 151       positions   NNS    151
# 152            that   WDT    152
# 153             fit   VBP    153
# 154            your  PRP$    154
# 155  qualifications   NNS    155
# 156               1    CD    156
# 157               ;     :    157

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# ## List of all example index/position

# %%
senDf = df.copy()
senDf
# Out:
#               Words   Pos  index
# 0                 ;     :      0
# 1               The    DT      1
# 2                is   VBZ      2
# 3                 a    DT      3
# 4               car    NN      4
# 5                10    CD      5
# 6                 ;     :      6
# 7                 ;     :      7
# 8              Will   NNP      8
# 9                is   VBZ      9
# 10          running   VBG     10
# 11                5    CD     11
# 12                ;     :     12
# 13                ;     :     13
# 14              The    DT     14
# 15              car    NN     15
# 16               is   VBZ     16
# 17              new    JJ     17
# 18                1    CD     18
# 19                ;     :     19
# 20                ;     :     20
# 21                I   PRP     21
# 22               'm   VBP     22
# 23           taking   VBG     23
# 24              the    DT     24
# 25            plane    NN     25
# 26                1    CD     26
# ...

# %%
# The list of all examlple index/position
indPos = senDf[senDf['Words']==";"]
indPos
# Out:
#     Words Pos  index
# 0       ;   :      0
# 6       ;   :      6
# 7       ;   :      7
# 12      ;   :     12
# 13      ;   :     13
# 19      ;   :     19
# 20      ;   :     20
# 27      ;   :     27
# 28      ;   :     28
# 53      ;   :     53
# 54      ;   :     54
# 59      ;   :     59
# 60      ;   :     60
# 64      ;   :     64
# 65      ;   :     65
# 70      ;   :     70
# 71      ;   :     71
# 77      ;   :     77
# 78      ;   :     78
# 84      ;   :     84
# 85      ;   :     85
# 93      ;   :     93
# 94      ;   :     94
# 102     ;   :    102
# 103     ;   :    103
# 113     ;   :    113
# 114     ;   :    114
# 121     ;   :    121
# 122     ;   :    122
# 141     ;   :    141
# 142     ;   :    142
# 157     ;   :    157

# %% [markdown]
# ## Adding examlpes id

# %%
# Create pair of index (Begin,End) of the example
splitedSize = 2
examplesIndex = [indPos.index[x:x+splitedSize] for x in range(0, len(indPos.index), splitedSize)]
examplesIndex
# Out:
# [Int64Index([0, 6], dtype='int64'),
#  Int64Index([7, 12], dtype='int64'),
#  Int64Index([13, 19], dtype='int64'),
#  Int64Index([20, 27], dtype='int64'),
#  Int64Index([28, 53], dtype='int64'),
#  Int64Index([54, 59], dtype='int64'),
#  Int64Index([60, 64], dtype='int64'),
#  Int64Index([65, 70], dtype='int64'),
#  Int64Index([71, 77], dtype='int64'),
#  Int64Index([78, 84], dtype='int64'),
#  Int64Index([85, 93], dtype='int64'),
#  Int64Index([94, 102], dtype='int64'),
#  Int64Index([103, 113], dtype='int64'),
#  Int64Index([114, 121], dtype='int64'),
#  Int64Index([122, 141], dtype='int64'),
#  Int64Index([142, 157], dtype='int64')]

# %%
df["sentence_id"] = ""
i = 1
for exa in examplesIndex:

    df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
    i =i+1
# Out:
# <ipython-input-338-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-338-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-338-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#               Words   Pos  index sentence_id
# 0                 ;     :      0           1
# 1               The    DT      1           1
# 2                is   VBZ      2           1
# 3                 a    DT      3           1
# 4               car    NN      4           1
# 5                10    CD      5           1
# 6                 ;     :      6           1
# 7                 ;     :      7           2
# 8              Will   NNP      8           2
# 9                is   VBZ      9           2
# 10          running   VBG     10           2
# 11                5    CD     11           2
# 12                ;     :     12           2
# 13                ;     :     13           3
# 14              The    DT     14           3
# 15              car    NN     15           3
# 16               is   VBZ     16           3
# 17              new    JJ     17           3
# 18                1    CD     18           3
# 19                ;     :     19           3
# ...

# %% [markdown]
# ## Examples score

# %%
df.head(25)
# Out:
#       Words  Pos  index sentence_id
# 0         ;    :      0           1
# 1       The   DT      1           1
# 2        is  VBZ      2           1
# 3         a   DT      3           1
# 4       car   NN      4           1
# 5        10   CD      5           1
# 6         ;    :      6           1
# 7         ;    :      7           2
# 8      Will  NNP      8           2
# 9        is  VBZ      9           2
# 10  running  VBG     10           2
# 11        5   CD     11           2
# 12        ;    :     12           2
# 13        ;    :     13           3
# 14      The   DT     14           3
# 15      car   NN     15           3
# 16       is  VBZ     16           3
# 17      new   JJ     17           3
# 18        1   CD     18           3
# 19        ;    :     19           3
# 20        ;    :     20           4
# 21        I  PRP     21           4
# 22       'm  VBP     22           4
# 23   taking  VBG     23           4
# 24      the   DT     24           4

# %%
#To find by ID the beginning and the end of example 
def get_example_position(data,id):
    result = data[data['sentence_id']==id]
    
    start = result.iloc[0]['index']
    end =  result.iloc[result.shape[0]-1]['index']
    
    return start,end

# %%
start,end = get_example_position(df,3)
start
# Out:
# 13

# %%
## Adding score column and define it as numeric 
df["Score"] = "1" #1 is the default value
df = df.astype({"Score": int, "sentence_id": int})

# %%
def set_example_score(data):
    
    # Get unique id of examples
    egs_id = df.sentence_id.unique()
    egs_id
    
    for eg_id in egs_id:
        
        #Get beginning and the end index of the example
        eg_start,eg_end = get_example_position(data,eg_id)
        
        #Get the score
        score = data.iloc[eg_end-1]['Words']

        #attribute the score
        data.iloc[eg_start:eg_end+1,[4]] = int(score)
        
    return data

# %%
df = set_example_score(df)

# %% [markdown]
# # Input

# %%
word1 = "verb"
word2 = "initiative"

# %% [markdown]
# ## Convert  input to a list

# %%
#Convert the input to a list to map with other format of the word 
word1 = [word1]
word2 = [word2]

# %% [markdown]
# ## Lowercase input

# %%
for i in range(len(word1)):
    word1[i] = word1[i].lower()

for i in range(len(word2)):
    word2[i] = word2[i].lower()

# %% [markdown]
# # POS tags dictionary

# %%
# nltk.help.upenn_tagset()

# %%
def tag_input(input):

    if input =='verb':
        input = ['VBZ','VBP','VBG','VB','VBD','VBN']
    
    elif input == 'adjective' :
        input = ['JJ','JJR','JJS','NN']
    
    elif input == 'adverb':
        input = ['RB','RBR','RBS']
    
    elif input == 'noun' or input == 'pronoun' :
        input = ['NN','NNP','NNPS','PRP','NNS','PRP$']
    
    else:
        return[input]
    
    return input

# %%
word1 = tag_input(word1[0])
word2 = tag_input(word2[0])

# %% [markdown]
# # Filtering

# %% [markdown]
# ## Filter 1

# %%
#Input: the index of the searched word
# Output: the position of the end of the example
def upperIndex(item,alist):
    #find the greater border index 
    position = np.argmax(alist > item)
    return alist[position]

# %%
res = df[(df['Words'].isin(word1)) | (df['Pos'].isin(word1))]
# res = df[(df['Words'].str.contains(word1)) | (df['Pos'].str.contains(word1))]
res['index'] = res.index
res
# Out:
# <ipython-input-353-774570324dd6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['index'] = res.index
#             Words  Pos  index  sentence_id  Score
# 2              is  VBZ      2            1     10
# 9              is  VBZ      9            2      5
# 10        running  VBG     10            2      5
# 16             is  VBZ     16            3      1
# 22             'm  VBP     22            4      1
# 23         taking  VBG     23            4      1
# 31            add  VBP     31            5      1
# 42           make   VB     42            5      1
# 56         filter   VB     56            6      1
# 67          embed   VB     67            8      1
# 73        started  VBD     73            9      1
# ...

# %%
# first filter passed
indices = res.iloc[:,2].values
indices
# Out:
# array([  2,   9,  10,  16,  22,  23,  31,  42,  56,  67,  73,  80,  87,
#         88,  96, 105, 116, 127, 129, 130, 137, 148, 153], dtype=int64)

# %% [markdown]
# ## Filter 2

# %%
word2
# Out:
# ['initiative']

# %%
##### Get the index of the good example
examplesPosition = []
for i in indices:
    
    #Get the end of the example
    endExample = upperIndex(i,indPos.index)

    if(i+1 < endExample):
        tmp= df.apply(lambda x: df.iloc[i+1].str.lower().isin(word2))
        if(tmp.Pos.Pos | tmp.Words.Words):
            examplesPosition.append(i)
    
    if(i+2 < endExample):
        tmp= df.apply(lambda x: df.iloc[i+2].str.lower().isin(word2))
        if(tmp.Pos.Pos | tmp.Words.Words):
            examplesPosition.append(i)
            
    if(i+3 < endExample):
        tmp= df.apply(lambda x: df.iloc[i+3].str.lower().isin(word2))
        if(tmp.Pos.Pos | tmp.Words.Words):
            examplesPosition.append(i)
    
examplesPosition
# Out:
# [73, 80, 88, 105, 116]

# %% [markdown]
# # Result

# %% [markdown]
# ## Get the good examples indices

# %%
# examplesPosition = indices

# %%
generalIndex = indPos.index.array
generalIndex
# Out:
# <PandasArray>
# [  0,   6,   7,  12,  13,  19,  20,  27,  28,  53,  54,  59,  60,  64,  65,
#   70,  71,  77,  78,  84,  85,  93,  94, 102, 103, 113, 114, 121, 122, 141,
#  142, 157]
# Length: 32, dtype: int64

# %%
#Find the list of index of the final example 
finalIndexList = []
for i in examplesPosition:
    #find the greater border index 
    position = np.argmax(generalIndex > i)
    finalIndexList.append(generalIndex[position])
    
    #Get the smaller border index
    indexes = [j for j, x in enumerate(generalIndex) if x < i]
    finalIndexList.append(generalIndex[max(indexes)])
    
finalIndexList.sort()
finalIndexList
# Out:
# [71, 77, 78, 84, 85, 93, 103, 113, 114, 121]

# %% [markdown]
# ## Create the examples pairs

# %%
splitedSize = 2
examplesIndex = [finalIndexList[x:x+splitedSize] for x in range(0, len(finalIndexList), splitedSize)]

# %%
examplesIndex
# Out:
# [[71, 77], [78, 84], [85, 93], [103, 113], [114, 121]]

# %% [markdown]
# ## Create the dataframe of the solution

# %%
# Create the solution dataframe
columns = ['Words','Pos']
finalSolution = pd.DataFrame(columns=columns)

for exa in examplesIndex:
    finalSolution = finalSolution.append(df.iloc[exa[0]:exa[1]])
finalSolution
# Out:
#           Words   Pos  index  sentence_id  Score
# 71            ;     :   71.0          9.0    1.0
# 72            I   PRP   72.0          9.0    1.0
# 73      started   VBD   73.0          9.0    1.0
# 74         this    DT   74.0          9.0    1.0
# 75   initiative    JJ   75.0          9.0    1.0
# 76            1    CD   76.0          9.0    1.0
# 78            ;     :   78.0         10.0    5.0
# 79           He   PRP   79.0         10.0    5.0
# 80   integrated   VBD   80.0         10.0    5.0
# 81           an    DT   81.0         10.0    5.0
# 82   initiative    JJ   82.0         10.0    5.0
# 83            5    CD   83.0         10.0    5.0
# 85            ;     :   85.0         11.0    1.0
# 86           It   PRP   86.0         11.0    1.0
# 87          has   VBZ   87.0         11.0    1.0
# 88         been   VBN   88.0         11.0    1.0
# 89            a    DT   89.0         11.0    1.0
# 90        great    JJ   90.0         11.0    1.0
# ...

# %%
finalSolution.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##  Sort final solution by score

# %%
finalSolution = finalSolution.sort_values(by=['Score','sentence_id'],ascending=False)

# %% [markdown]
# # Show the final answer

# %%
def print_result(data,sep):
    
    df_list = data.Words.values.tolist()
    for x in range(len(df_list)):
        if(df_list[x] == sep):
            print("\n")
            continue
        print(df_list[x], end=" ")

# %%
print_result(finalSolution,";")
# Out:
# It is the dearest initiative to my heart 10
#
# It is a bigger initiative 7
#
# He integrated an initiative 5
#
# It has been a great initiative 1
#
# I started this initiative 1

# %% [markdown]
# # Update source File
