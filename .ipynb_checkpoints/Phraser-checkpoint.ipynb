# %% [markdown]
# # Import

# %%
import nltk
import pandas as pd
import numpy as np

# %% [markdown]
# # Installlation

# %%
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('brown')
# nltk.download('tagsets')
# nltk.download('gutenberg')
# nltk.download('genesis')
# nltk.download('inaugural')
# nltk.download('nps_chat')
# !pip install xeus-python notebook
# Out:
# Requirement already satisfied: xeus-python in d:\anconda\lib\site-packages (0.12.5)
# Requirement already satisfied: notebook in d:\anconda\lib\site-packages (6.1.4)
# Requirement already satisfied: ipython<8,>=7.20 in d:\anconda\lib\site-packages (from xeus-python) (7.26.0)
# Requirement already satisfied: pygments<3,>=2.3.1 in d:\anconda\lib\site-packages (from xeus-python) (2.7.2)
# Requirement already satisfied: debugpy>=1.1.0 in d:\anconda\lib\site-packages (from xeus-python) (1.4.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in d:\anconda\lib\site-packages (from notebook) (4.6.3)
# Requirement already satisfied: ipython-genutils in d:\anconda\lib\site-packages (from notebook) (0.2.0)
# Requirement already satisfied: argon2-cffi in d:\anconda\lib\site-packages (from notebook) (20.1.0)
# Requirement already satisfied: nbformat in d:\anconda\lib\site-packages (from notebook) (5.0.8)
# Requirement already satisfied: ipykernel in d:\anconda\lib\site-packages (from notebook) (5.3.4)
# Requirement already satisfied: tornado>=5.0 in d:\anconda\lib\site-packages (from notebook) (6.1)
# Requirement already satisfied: nbconvert in d:\anconda\lib\site-packages (from notebook) (6.0.7)
# Requirement already satisfied: Send2Trash in d:\anconda\lib\site-packages (from notebook) (1.5.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\anconda\lib\site-packages (from notebook) (6.1.7)
# Requirement already satisfied: traitlets>=4.2.1 in d:\anconda\lib\site-packages (from notebook) (5.0.5)
# Requirement already satisfied: pyzmq>=17 in d:\anconda\lib\site-packages (from notebook) (19.0.2)
# Requirement already satisfied: jinja2 in d:\anconda\lib\site-packages (from notebook) (2.11.2)
# Requirement already satisfied: prometheus-client in d:\anconda\lib\site-packages (from notebook) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anconda\lib\site-packages (from notebook) (0.9.1)
# Requirement already satisfied: setuptools>=18.5 in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (50.3.1.post20201107)
# Requirement already satisfied: decorator in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (3.0.8)
# Requirement already satisfied: backcall in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (0.17.1)
# Requirement already satisfied: matplotlib-inline in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (0.1.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (0.4.4)
# Requirement already satisfied: pickleshare in d:\anconda\lib\site-packages (from ipython<8,>=7.20->xeus-python) (0.7.5)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in d:\anconda\lib\site-packages (from jupyter-core>=4.6.1->notebook) (227)
# Requirement already satisfied: cffi>=1.0.0 in d:\anconda\lib\site-packages (from argon2-cffi->notebook) (1.14.3)
# Requirement already satisfied: six in d:\anconda\lib\site-packages (from argon2-cffi->notebook) (1.15.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\anconda\lib\site-packages (from nbformat->notebook) (3.2.0)
# Requirement already satisfied: defusedxml in d:\anconda\lib\site-packages (from nbconvert->notebook) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\anconda\lib\site-packages (from nbconvert->notebook) (0.3)
# Requirement already satisfied: testpath in d:\anconda\lib\site-packages (from nbconvert->notebook) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in d:\anconda\lib\site-packages (from nbconvert->notebook) (0.1.2)
# Requirement already satisfied: bleach in d:\anconda\lib\site-packages (from nbconvert->notebook) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anconda\lib\site-packages (from nbconvert->notebook) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\anconda\lib\site-packages (from nbconvert->notebook) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anconda\lib\site-packages (from nbconvert->notebook) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.1 in d:\anconda\lib\site-packages (from jupyter-client>=5.3.4->notebook) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anconda\lib\site-packages (from jinja2->notebook) (1.1.1)
# Requirement already satisfied: pywinpty>=0.5 in d:\anconda\lib\site-packages (from terminado>=0.8.3->notebook) (0.5.7)
# Requirement already satisfied: wcwidth in d:\anconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8,>=7.20->xeus-python) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\anconda\lib\site-packages (from jedi>=0.16->ipython<8,>=7.20->xeus-python) (0.7.0)
# Requirement already satisfied: pycparser in d:\anconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook) (2.20)
# Requirement already satisfied: attrs>=17.4.0 in d:\anconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\anconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (0.17.3)
# Requirement already satisfied: packaging in d:\anconda\lib\site-packages (from bleach->nbconvert->notebook) (20.4)
# Requirement already satisfied: webencodings in d:\anconda\lib\site-packages (from bleach->nbconvert->notebook) (0.5.1)
# Requirement already satisfied: async-generator in d:\anconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook) (1.10)
# Requirement already satisfied: nest-asyncio in d:\anconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook) (1.4.2)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anconda\lib\site-packages (from packaging->bleach->nbconvert->notebook) (2.4.7)

# %% [markdown]
# # To-do list

# %% [markdown]
# - Create dictionary for the POS shortcuts
# - Create a Json answer for the API
# - Handle the space before and after "."
# - Searching by lemma/origin of the word "Clean text"

# %% [markdown]
# # Load dataset

# %%
file = open('nltk.txt')
read_file = file.read()
text = nltk.Text(nltk.word_tokenize(read_file))
tags = nltk.pos_tag(text)
words = [word for (word, pos) in nltk.pos_tag(text)]
pos = [pos for (word, pos) in nltk.pos_tag(text)]
# match = text.concordance('car')

# %%
prh = {'Words':words,'Pos':pos}
df = pd.DataFrame(prh)

# %%
df['index']= df.index

# %%
df.tail(20)
# Out:
#           Words   Pos  index
# 88         this    DT     88
# 89   initiative    NN     89
# 90            .     .     90
# 91            .     .     91
# 92           It   PRP     92
# 93           is   VBZ     93
# 94          the    DT     94
# 95      dearest    NN     95
# 96   initiative    NN     96
# 97           to    TO     97
# 98           my  PRP$     98
# 99        heart    NN     99
# 100           .     .    100
# 101           .     .    101
# 102          It   PRP    102
# 103          is   VBZ    103
# 104           a    DT    104
# 105      bigger   JJR    105
# 106  initiative    NN    106
# 107           .     .    107

# %% [markdown]
# ## List of all example index/position

# %%
senDf = df.copy()
senDf
# Out:
#           Words  Pos  index
# 0             .    .      0
# 1           The   DT      1
# 2            is  VBZ      2
# 3             a   DT      3
# 4           car   NN      4
# ..          ...  ...    ...
# 103          is  VBZ    103
# 104           a   DT    104
# 105      bigger  JJR    105
# 106  initiative   NN    106
# 107           .    .    107
#
# [108 rows x 3 columns]

# %%
# The list of all examlple index/position
indPos = senDf[senDf['Words']=="."]
indPos
# Out:
#     Words Pos  index
# 0       .   .      0
# 5       .   .      5
# 6       .   .      6
# 10      .   .     10
# 11      .   .     11
# 16      .   .     16
# 17      .   .     17
# 23      .   .     23
# 24      .   .     24
# 48      .   .     48
# 49      .   .     49
# 53      .   .     53
# 54      .   .     54
# 57      .   .     57
# 58      .   .     58
# 62      .   .     62
# 63      .   .     63
# 68      .   .     68
# 69      .   .     69
# 74      .   .     74
# 75      .   .     75
# 82      .   .     82
# 83      .   .     83
# 90      .   .     90
# 91      .   .     91
# 100     .   .    100
# 101     .   .    101
# 107     .   .    107

# %% [markdown]
# # Adding sentance id

# %%
# Create pair of index (Begin,End) of the example
splitedSize = 2
examplesIndex = [indPos.index[x:x+splitedSize] for x in range(0, len(indPos.index), splitedSize)]
examplesIndex
# Out:
# [Int64Index([0, 5], dtype='int64'),
#  Int64Index([6, 10], dtype='int64'),
#  Int64Index([11, 16], dtype='int64'),
#  Int64Index([17, 23], dtype='int64'),
#  Int64Index([24, 48], dtype='int64'),
#  Int64Index([49, 53], dtype='int64'),
#  Int64Index([54, 57], dtype='int64'),
#  Int64Index([58, 62], dtype='int64'),
#  Int64Index([63, 68], dtype='int64'),
#  Int64Index([69, 74], dtype='int64'),
#  Int64Index([75, 82], dtype='int64'),
#  Int64Index([83, 90], dtype='int64'),
#  Int64Index([91, 100], dtype='int64'),
#  Int64Index([101, 107], dtype='int64')]

# %%
df["sentence_id"] = ""
i = 1
for exa in examplesIndex:

    df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
    i =i+1
# Out:
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i
# <ipython-input-937-d14aa2722008>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence_id'][(df['index']>=exa[0]) & (df['index']<=exa[1] )] = i

# %%
df.tail(20)
# Out:
#           Words   Pos  index sentence_id
# 88         this    DT     88          12
# 89   initiative    NN     89          12
# 90            .     .     90          12
# 91            .     .     91          13
# 92           It   PRP     92          13
# 93           is   VBZ     93          13
# 94          the    DT     94          13
# 95      dearest    NN     95          13
# 96   initiative    NN     96          13
# 97           to    TO     97          13
# 98           my  PRP$     98          13
# 99        heart    NN     99          13
# 100           .     .    100          13
# 101           .     .    101          14
# 102          It   PRP    102          14
# 103          is   VBZ    103          14
# 104           a    DT    104          14
# 105      bigger   JJR    105          14
# 106  initiative    NN    106          14
# 107           .     .    107          14

# %% [markdown]
# # Input

# %%
word1 = "Challenge"
word2 = "verb"

# %% [markdown]
# ## Convert  input to a list

# %%
#Convert the input to a list to group some inputs 
word1 = [word1]
word2 = [word2]

# %% [markdown]
# ## Lowercase input

# %%
for i in range(len(word1)):
    word1[i] = word1[i].lower()

for i in range(len(word2)):
    word2[i] = word2[i].lower()

# %% [markdown]
# # POS tags dictionary

# %%
# nltk.help.upenn_tagset()

# %%
def tag_input(input):

    if input =='verb':
        input = ['VBZ','VBP','VBG','VB','VBD','VBN']
    
    elif input == 'adjective' :
        input = ['JJ','JJR','JJS','NN']
    
    elif input == 'adverb':
        input = ['RB','RBR','RBS']
    
    elif input == 'noun' or input == 'pronoun' :
        input = ['NN','NNP','NNPS','PRP','NNS','PRP$']
    
    else:
        return[input]
    
    return input

# %%
word1 = tag_input(word1[0])
word2 = tag_input(word2[0])

# %%
word1
# Out:
# ['JJ', 'JJR', 'JJS', 'NN']

# %% [markdown]
# # Filtering

# %% [markdown]
# ## Filter 1

# %%
#Input: the index of the searched word
# Output: the position of the end of the example
def upperIndex(item,alist):
    #find the greater border index 
    position = np.argmax(alist > item)
    return alist[position]

# %%
res = df[(df['Words'].isin(word1)) | (df['Pos'].isin(word1))]
# res = df[(df['Words'].str.contains(word1)) | (df['Pos'].str.contains(word1))]
res['index'] = res.index
res
# Out:
# <ipython-input-947-774570324dd6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['index'] = res.index
#           Words  Pos  index sentence_id
# 4           car   NN      4           1
# 13          car   NN     13           3
# 15          new   JJ     15           3
# 22        plane   NN     22           4
# 29   irrelevant   JJ     29           5
# 33        model   NN     33           5
# 40        model   NN     40           5
# 41        worst  JJS     41           5
# 55      wrapper   JJ     55           7
# 67   initiative   NN     67           9
# 73   initiative   NN     73          10
# 80        great   JJ     80          11
# 81   initiative   NN     81          11
# 89   initiative   NN     89          12
# 95      dearest   NN     95          13
# 96   initiative   NN     96          13
# 99        heart   NN     99          13
# 105      bigger  JJR    105          14
# 106  initiative   NN    106          14

# %%
# first filter passed
indices = res.iloc[:,2].values
indices
# Out:
# array([  4,  13,  15,  22,  29,  33,  40,  41,  55,  67,  73,  80,  81,
#         89,  95,  96,  99, 105, 106], dtype=int64)

# %% [markdown]
# ## Filter 2

# %%
word2
# Out:
# ['initiative']

# %%
##### Get the index of the good example
examplesPosition = []
for i in indices:
    
    #Get the end of the example
    endExample = upperIndex(i,indPos.index)

    if(i+1 < endExample):
        tmp= df.apply(lambda x: df.iloc[i+1].str.lower().isin(word2))
        if(tmp.Pos.Pos | tmp.Words.Words):
            examplesPosition.append(i)
    
    if(i+2 < endExample):
        tmp= df.apply(lambda x: df.iloc[i+2].str.lower().isin(word2))
        if(tmp.Pos.Pos | tmp.Words.Words):
            examplesPosition.append(i)
            
    if(i+3 < endExample):
        tmp= df.apply(lambda x: df.iloc[i+3].str.lower().isin(word2))
        if(tmp.Pos.Pos | tmp.Words.Words):
            examplesPosition.append(i)
    
examplesPosition
# Out:
# [80, 95, 105]

# %% [markdown]
# # Result

# %% [markdown]
# ## Get the good examples indices

# %%
# examplesPosition = indices

# %%
generalIndex = indPos.index.array
generalIndex
# Out:
# <PandasArray>
# [  0,   5,   6,  10,  11,  16,  17,  23,  24,  48,  49,  53,  54,  57,  58,
#   62,  63,  68,  69,  74,  75,  82,  83,  90,  91, 100, 101, 107]
# Length: 28, dtype: int64

# %%
#Find the list of index of the final example 
finalIndexList = []
for i in examplesPosition:
    #find the greater border index 
    position = np.argmax(generalIndex > i)
    finalIndexList.append(generalIndex[position])
    
    #Get the smaller border index
    indexes = [j for j, x in enumerate(generalIndex) if x < i]
    finalIndexList.append(generalIndex[max(indexes)])
    
finalIndexList.sort()
finalIndexList
# Out:
# [75, 82, 91, 100, 101, 107]

# %% [markdown]
# ## Create the examples pairs

# %%
splitedSize = 2
examplesIndex = [finalIndexList[x:x+splitedSize] for x in range(0, len(finalIndexList), splitedSize)]

# %%
examplesIndex
# Out:
# [[75, 82], [91, 100], [101, 107]]

# %% [markdown]
# ## Create the dataframe of the solution

# %%
# Create the solution dataframe
columns = ['Words','Pos']
finalSolution = pd.DataFrame(columns=columns)

for exa in examplesIndex:
    finalSolution = finalSolution.append(df.iloc[exa[0]:exa[1]])
finalSolution
# Out:
#           Words   Pos  index sentence_id
# 75            .     .   75.0          11
# 76           It   PRP   76.0          11
# 77          has   VBZ   77.0          11
# 78         been   VBN   78.0          11
# 79            a    DT   79.0          11
# 80        great    JJ   80.0          11
# 81   initiative    NN   81.0          11
# 91            .     .   91.0          13
# 92           It   PRP   92.0          13
# 93           is   VBZ   93.0          13
# 94          the    DT   94.0          13
# 95      dearest    NN   95.0          13
# 96   initiative    NN   96.0          13
# 97           to    TO   97.0          13
# 98           my  PRP$   98.0          13
# 99        heart    NN   99.0          13
# 101           .     .  101.0          14
# 102          It   PRP  102.0          14
# 103          is   VBZ  103.0          14
# 104           a    DT  104.0          14
# 105      bigger   JJR  105.0          14
# 106  initiative    NN  106.0          14

# %%
finalSolution.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Show the final answer

# %%
print(' '.join(str(x) for x in [finalSolution.Words]))
# Out:
# 0              .
# 1             It
# 2            has
# 3           been
# 4              a
# 5          great
# 6     initiative
# 7              .
# 8             It
# 9             is
# 10           the
# 11       dearest
# 12    initiative
# 13            to
# 14            my
# 15         heart
# 16             .
# 17            It
# 18            is
# 19             a
# 20        bigger
# 21    initiative
# Name: Words, dtype: object
